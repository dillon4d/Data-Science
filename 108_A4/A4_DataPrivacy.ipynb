# %% [markdown]
# # COGS 108 - Assignment 4: Data Privacy
#
# This assignment covers getting data (web scraping) and data privacy (Safe Harbor).
#
# This assignment is out of 7.5 points, worth 7.5% of your grade.
#
# **PLEASE DO NOT CHANGE THE NAME OF THIS FILE.**
#
# **PLEASE DO NOT COPY & PASTE OR DELETE CELLS INLCUDED IN THE ASSIGNMENT.**

# %% [markdown]
# ## Important Reminders
#
# - Do not change / update / delete any existing cells with 'assert' in them. These are the tests used to check your assignment.
# - This assignment has hidden tests: tests that are not visible here, but that will be run on your submitted file. Passing all the tests you can see in the notebook here does not guarantee you have the right answer.

# %% [markdown]
# ## Overview
#
# We have briefly discussed in lecture the importance and the mechanics of protecting individuals' privacy when they are included in datasets.
#
# One method to do so is the Safe Harbor Method. The Safe Harbor method specifies how to protect individuals' identities by telling us which information to remove from a dataset in order to avoid accidently disclosing personal information.
#
# In this assignment, we will explore web scraping, which can often include personally identifiable information, how identity can be decoded from badly anonymized datasets, and also explore using Safe Harbor to anonymize datasets properly.
#
# The topics covered in this assignment are mainly covered in the 'DataGathering' and 'DataPrivacy&Anonymization' COGS 108 [Tutorial notebooks](https://github.com/COGS108/Tutorials).

# %%
# Imports - these are provided for you. Do not import any other packages.
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup

# %% [markdown]
# ## Part 1: Web Scraping (1.25 points)

# %% [markdown]
# ### Scraping Rules
#
# 1) If you are using another organization's website for scraping, make sure to check the website's terms & conditions.
#
# 2) Do not request data from the website too aggressively (quickly) with your program (also known as spamming), as this may break the website. Make sure your program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
#
# 3) The layout of a website may change from time to time. Because of this, if you're scraping a website, make sure to revisit the site and rewrite your code as needed.

# %% [markdown]
# ### 1a) Web Scrape
#
# We will first retrieve the contents on a page and examine them a bit.
#
# Make a variable called `wiki`, that stores the following URL (as a string):
# https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population
#
# Now, to open the URL, use `requests.get()` and provide `wiki` as its input. Store this in a variable called `page`.
#
# After that, make a variable called `soup` to parse the HTML using `BeautifulSoup`. Consider that there will be a method from `BeautifulSoup` that you'll need to call on to get the content from the page.

# %%
wiki = 'https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population'

page = requests.get(wiki)

soup = BeautifulSoup(page.text, 'lxml')
wiki
# Out:
# 'https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population'

# %%
assert wiki
assert page
assert soup

# %% [markdown]
# ### 1b) Checking Scrape Contents
#
# Extract the title from the page and save it in a variable called `title_page`.
#
# Make sure you extract it as a string.
#
# To do so, you have to use the soup object created in the above cell.
# Hint: from your soup variable, you can access this with `.title.string`.
#
# Make sure you print out and check the contents of `title_page`.
#
# Note that it should not have any tags (such as `<title>` included in it).

# %%
title_page = soup.title.string

print(title_page)
# Out:
# List of states and territories of the United States by population - Wikipedia

# %%
assert title_page
assert isinstance(title_page, str)

# %% [markdown]
# ### 1c) Extracting Tables
#
# In order to extract the data we want, we'll start with extracting a data table of interest.
#
# Note that you can see this table by going to look at the link we scraped.
#
# Use the `soup` object and call a method called `find`, which will find and extract the first table in the scraped webpage. Store this in the variable `right_table`.
#
# Note: you need to search for the name `table`, and set the `class_` argument as `wikitable sortable`.

# %%
right_table = soup.find("table", { "class" : "wikitable sortable" })

# %%
assert right_table
assert isinstance(right_table, bs4.element.Tag)
assert right_table.name == 'table'

# %% [markdown]
# Now, you'll extract the data from the table into lists.
#
# Note: This code is provided for you. Do read through it and try to see how it works.

# %%
# CODE PROVIDED
# YOU SHOULD NOT HAVE TO EDIT
# BUT YOU WILL WANT TO UNDERSTAND
list_a, list_b, list_c = [], [], []

for row in right_table.findAll('tr'):
    
    cells = row.findAll('td')
    
    # Skips rows that aren't 10 columns long (like the heading)
    if len(cells) != 12:
        continue

    # This catches when the name cells stops having a link
    #  and ends, skipping the last (summary rows)
    try:
        list_a.append(cells[2].find('a').text)
        list_b.append(cells[3].find(text=True))
        list_c.append(cells[4].find(text=True))
    except:
        break

# %% [markdown]
# ### 1d) Collecting into a dataframe
#
# Create a dataframe `my_df` and add the data from the lists above to it.
# - `list_a` is the state or territory name. Set the column name as `State`, and make this the index
# - `list_b` is the population estimate. Add it to the dataframe, and set the column name as `Population Estimate`
# - `list_c` is the census population. Add it to the dataframe, and set the column name as `Census Population`
#
# make sure to check the head of your dataframe to see that everything looks right! ie: my_df.head()

# %%
my_df = pd.DataFrame({'State': list_a,'Population Estimate': list_b,'Census Population': list_c})
my_df.set_index('State', inplace=True)
my_df.head()
# Out:
# Empty DataFrame
# Columns: [Population Estimate, Census Population]
# Index: []

# %%
assert isinstance (my_df, pd.DataFrame)
assert my_df.index.name == 'State'
assert list(my_df.columns) == ['Population Estimate', 'Census Population']

# %% [markdown]
# ### 1e) Using the data
# What is the Population Estimate of California? Save this answer to a variable called `ca_pop`
# Notes:
# - Extract this value programmatically from your dataframe (as in, don't set it explicitly as `ca_pop = 123`)
# - You can use `.loc` to extract a particular value from a dataframe.
# - The data in your dataframe will be strings - that's fine, leave them as strings (don't typecast).
# - Strip any whitespace/newline characters from this string, if necessary. (`rstrip()` may be helpful)

# %%
ca_pop = my_df.get_value('California', 'Population Estimate').rstrip('\n')

ca_pop
# Out:
# C:\Users\Dillon\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# TypeError: must be real number, not str
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'California'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# TypeError: must be real number, not str
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-8f94ac66440f> in <module>
# ----> 1 ca_pop = my_df.get_value('California', 'Population Estimate').rstrip('\n')
#       2
#       3 ca_pop
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in get_value(self, index, col, takeable)
#    2818             stacklevel=2,
#    2819         )
# -> 2820         return self._get_value(index, col, takeable=takeable)
#    2821
#    2822     def _get_value(self, index, col, takeable=False):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    2842         # use positional
#    2843         col = self.columns.get_loc(col)
# -> 2844         index = self.index.get_loc(index)
#    2845         return self._get_value(index, col, takeable=True)
#    2846
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\numeric.py in get_loc(self, key, method, tolerance)
#     477         except (TypeError, NotImplementedError):
#     478             pass
# --> 479         return super().get_loc(key, method=method, tolerance=tolerance)
#     480
#     481     @cache_readonly
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'California'

# %%
assert ca_pop

# %% [markdown]
# ## Part 2: Identifying Data (3 points)

# %% [markdown]
# Data Files:
# - anon_user_dat.json
# - employee_info.json
#
# You will first be working with a file called 'anon_user_dat.json'. This file contains information about some (fake) Tinder users. When creating an account, each Tinder user was asked to provide their first name, last name, work email (to verify the disclosed workplace), age, gender, phone # and zip code. Before releasing this data, a data scientist cleaned the data to protect the privacy of Tinder's users by removing the obvious personal identifiers: phone #, zip code, and IP address. However, the data scientist chose to keep each users' email addresses because when they visually skimmed a couple of the email addresses none of them seemed to have any of the users' actual names in them. This is where the data scientist made a huge mistake!
#
# We will take advantage of having the work email addresses by finding the employee information of different companies and matching that employee information with the information we have, in order to identify the names of the secret Tinder users!

# %% [markdown]
# ### 2a) Load in the 'cleaned' data
#
# Load the `anon_user_dat.json` json file into a pandas dataframe. Call it `df_personal`.

# %%
df_personal = pd.read_json('anon_user_dat.json')
df_personal.head()
# Out:
#    age                        email  gender
# 0   60  gshoreson0@seattletimes.com    Male
# 1   47           eweaben1@salon.com  Female
# 2   27      akillerby2@gravatar.com    Male
# 3   46            gsainz3@zdnet.com    Male
# 4   72     bdanilewicz4@4shared.com    Male

# %%
assert isinstance(df_personal, pd.DataFrame)

# %% [markdown]
# ### 2b) Check the first 10 emails
#
# Save the first 10 emails to a Series, and call it `sample_emails`.
# You should then print out this Series. ( Use print() )
#
# The purpose of this is to get a sense of how these work emails are structured and how we could possibly extract where each anonymous user seems to work.

# %%
sample_emails = df_personal.loc[:9, 'email']
sample_emails
# Out:
# 0    gshoreson0@seattletimes.com
# 1             eweaben1@salon.com
# 2        akillerby2@gravatar.com
# 3              gsainz3@zdnet.com
# 4       bdanilewicz4@4shared.com
# 5      sdeerness5@wikispaces.com
# 6         jstillwell6@ustream.tv
# 7         mpriestland7@opera.com
# 8       nerickssen8@hatena.ne.jp
# 9             hparsell9@xing.com
# Name: email, dtype: object

# %%
assert isinstance(sample_emails, pd.Series)

# %% [markdown]
# ### 2c) Extract the Company Name From the Email
#
# Create a function with the following specifications:
# - Function Name: extract_company
# - Purpose: to extract the company of the email (i.e., everything after the @ sign but before the first .)
# - Parameter(s): email (string)
# - Returns: The extracted part of the email (string)
# - Hint: This should take 1 line of code. Look into the find('') method.
#
# You can start with this outline:
# ```python
# def extract_company(email):
#     return
# ```
#
# Example Usage:
# - extract_company("larhe@uber.com") should return "uber"
# - extract_company(“ds@cogs.edu”) should return “cogs”

# %%
def extract_company(email):
    return email.split('@')[-1].split('.')[0]

# %%
assert extract_company("gshoreson0@seattletimes.com") == "seattletimes"
assert extract_company("amcgeffen1d@goo.ne.jp") == 'goo'

# %% [markdown]
# With a little bit of basic sleuthing (aka googling) and web-scraping (aka selectively reading in html code) it turns out that you've been able to collect information about all the present employees/interns of the companies you are interested in. Specifically, on each company website, you have found the name, gender, and age of its employees. You have saved that info in employee_info.json and plan to see if, using this new information, you can match the Tinder accounts to actual names.

# %% [markdown]
# ### 2d) Load in employee data
#
# Load the json file into a pandas dataframe. Call it `df_employee`.

# %%
df_employee = pd.read_json('employee_info.json')

# %%
assert isinstance(df_employee, pd.DataFrame)

# %% [markdown]
# ### 2e) Match the employee name with company, age, gender
#
# Create a function with the following specifications:
# - Function name: employee_matcher
# - Purpose: to match the employee name with the provided company, age, and gender
# - Parameter(s): company (string), age (int), gender (string)
# - Returns: The employee first_name and last_name like this: return first_name, last_name
# - Note: If there are multiple employees that fit the same description, first_name and last_name should return a list of all possible first names and last names i.e., ['Desmund', 'Kelby'], ['Shepley', 'Tichner']. Note that the names of the individuals that would produce this output are 'Desmund Shepley' and 'Kelby Tichner'.
#
# Hint:
# There are many different ways to code this. An inelegant solution is to loop through `df_employee`
#    and for each data item see if the company, age, and gender match
#    i.e.,
#    ```python
#    for i in range(0, len(df_employee)):
#              if (company == df_employee.loc[i,'company']):
#    ```
#
# However! The solution above is very inefficient and long, so you should try to look into this:
# Google the df.loc method: It extracts pieces of the dataframe
#    if it fulfills a certain condition.
#    i.e.,
#
# ```python
# df_employee.loc[df_employee['company'] == company]
# ```
#
# If you need to convert your pandas data series into a list, you can do ```list(result)``` where result is a pandas "series"
#
# You can start with this outline:
# ```python
# def employee_matcher(company, age, gender):
#     return first_name, last_name
# ```

# %%
# Function to match employees company, age, gender to name
def employee_matcher(company, age, gender):
    
    # Match employees by their company, age, and gender
    emp_match = df_employee[(df_employee['company'] == company) & 
                        (df_employee['age'] == age) & 
                        (df_employee['gender'] == gender)]
    
    # Return employee first and last name as lists
    return (emp_match.first_name).values.tolist(), (emp_match.last_name).values.tolist()

#Test
employee_matcher("google", 41, "Male")
# Out:
# (['Maxwell'], ['Jorio'])

# %%
assert employee_matcher("google", 41, "Male") == (['Maxwell'], ['Jorio'])
assert employee_matcher("salon", 47, "Female") == (['Elenore'], ['Gravett'])
assert employee_matcher("webmd", 28, "Nonbinary") == (['Zaccaria'], ['Bartosiak'])

# %% [markdown]
# ### 2f) Extract all the private data
#
# - Create 2 empty lists called `first_names` and `last_names`
# - Loop through all the people we are trying to identify in df_personal
# - Call the `extract_company` function (i.e., `extract_company(df_personal.loc[i, 'email'])` )
# - Call the `employee_matcher` function
# - Append the results of `employee_matcher` to the appropriate lists (`first_names` and `last_names`)

# %%
first_names = [] 
last_names = [] 

for person in df_personal.index: 
    
    email = extract_company(df_personal.loc[person, 'email']) 
    age = df_personal.loc[person, 'age'] 
    gender = df_personal.loc[person, 'gender']
    value = employee_matcher(email, age, gender) 
    
    first_names.append(value[0]) 
    last_names.append(value[1])

# %%
assert first_names[45:50]== [['Justino'], ['Tadio'], ['Kennith'], ['Cedric'], ['Amargo']]
assert last_names[45:50] == [['Corro'], ['Blackford'], ['Milton'], ['Yggo'], ['Grigor']]

# %% [markdown]
# ### 2g) Add the names to the original 'secure' dataset!
#
# We have done this last step for you below, all you need to do is run this cell.
#
# For your own personal enjoyment, you should also print out the new `df_personal` with the identified people.

# %%
df_personal['first_name'] = first_names
df_personal['last_name'] = last_names

# %%
print(df_personal)
# Out:
#      age                        email  gender           first_name  \
# 0     60  gshoreson0@seattletimes.com    Male             [Gordon]
# 1     47           eweaben1@salon.com  Female            [Elenore]
# 2     27      akillerby2@gravatar.com    Male               [Abbe]
# 3     46            gsainz3@zdnet.com    Male              [Guido]
# 4     72     bdanilewicz4@4shared.com    Male              [Brody]
# ..   ...                          ...     ...                  ...
# 995    3        pstroulgerrn@time.com  Female           [Penelopa]
# 996   49  kbasnettro@seattletimes.com  Female  [Anthiathia, Kandy]
# 997   75  pmortlockrp@liveinternet.ru    Male               [Paco]
# 998   81         sphetterq@toplist.cz    Male              [Sammy]
# 999   70        jtyresrr@slashdot.org    Male             [Josiah]
#
#              last_name
# 0          [DelaField]
# 1            [Gravett]
# 2          [Stockdale]
# 3            [Comfort]
# 4           [Pinckard]
# ..                 ...
# 995            [Roman]
# 996  [Baldwin, Cossam]
# 997      [Weatherburn]
# 998           [Dymick]
# 999         [Ayshford]
#
# [1000 rows x 5 columns]

# %% [markdown]
# We have now just discovered the 'anonymous' identities of all the registered Tinder users...awkward.

# %% [markdown]
# ## Part 3: Anonymize Data (3.25 points)

# %% [markdown]
# You are hopefully now convinced that with some seemingly harmless data a hacker can pretty easily discover the identities of certain users. Thus, we will now clean the original Tinder data ourselves according to the Safe Harbor Method in order to make sure that it has been *properly* cleaned...

# %% [markdown]
# ### 3a) Load in personal data
#
# Load the `user_dat.csv` file into a pandas dataframe, being sure to read the zip codes (`zip`) in as a string.
#
# Store this in `df_users`.

# %%
df_users = pd.read_csv('user_dat.csv', dtype={'zip': 'str'})

# %%
df_users['zip'].dtype
# Out:
# dtype('O')

# %%
assert isinstance(df_users, pd.DataFrame)

# %% [markdown]
# ### 3b) Drop personal attributes
#
# Remove any personal information, following the Safe Harbor method.
# Based on the Safe Harbor method, remove any columns from `df_users` that contain personal information.
#
# Note that details on the Safe Harbor method are covered in the Tutorials.

# %%
# YOUR CODE HERE
df_users = df_users.drop(['email','first_name','last_name','ip_address','phone'], axis =1)

# %%
assert len(df_users.columns) == 3

# %% [markdown]
# ### 3c) Drop ages that are above 90
#
# Safe Harbor rule C: Drop all the rows which have age greater than 90 from `df_users`.

# %%
df_users = df_users[df_users['age'] <= 90]
df_users
# Out:
#      age  gender    zip
# 0     53  Female  01012
# 1     52    Male  01022
# 2     52  Female  01037
# 3     78     NaN  01086
# 4     19    Male  01344
# ..   ...     ...    ...
# 945   41    Male  99648
# 946   49  Female  99654
# 947   33    Male  99749
# 948   16    Male  99759
# 949   59    Male  99762
#
# [943 rows x 3 columns]

# %%
assert df_users.shape == (943, 3)

# %% [markdown]
# ### 3d) Load in zip code data
#
# Load the zip_pop.csv file into a (different) pandas dataframe. Call it `df_zip`.
#
# Note that the zip data should be read in as strings, not ints, as would be the default.
#
# In `read_csv`, use the parameter `dtype` to specify to read `zip` as str, and `population` as int.

# %%
df_zip = pd.read_csv('zip_pop.csv', dtype={'zip': str, 'population':int})

# %%
assert isinstance(df_zip, pd.DataFrame)

# %%
df_zip['population'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# ### 3e) Sort zipcodes into "Geographic Subdivision"
#
# The Safe Harbor Method applies to "Geographic Subdivisions" as opposed to each zipcode itself.
#
# Geographic Subdivision: All areas which share the first 3 digits of a zip code
#
# Count the total population for each geographic subdivision, storing the first 3 digits of the zip code and its corresponding population in the dictionary `zip_dict`. (For example, if there were 20 people whose zip code started with 090, the key-value pair in `zip_dict` would be `{'090' : 20}`.)
#
# You may be tempted to write a gnarly loop to accomplish this. Avoid that temptation. Instead, you'll want to be savy with a dictionary and `groupby` from `pandas` here.
#
# To get you started...
#
# If you wanted to group by whole zip code, you could use something like this:
#
# ```python
# df_zip.groupby(df_zip['zip'])
# ```
#
# But, we don't want to group by the *entire* zip code. Instead, we want to extract the first 3 digits of a zip code, and group by that.
#
# To extract the first three digits, you could so something like the following:
#
# ```python
# df_zip['zip'].str[:3]
# ```
#
# You'll want to combine these two concepts, such that you store this information in a dictionary `zip_dict`, which stores the first three digits of the zip code as the key and the population of that 3-digit zip code as the value.
#
# (If you're stuck and/or to better understand how dictionaries work and how they apply to this concept, check the section materials, use google, and go to discussion sections!)

# %%
# group dataframe by ('key')['value'].method() 
zip_dict = df_zip.groupby(df_zip['zip'].str[:3])['population'].sum().to_dict()

zip_dict
# Out:
# {'010': 469375,
#  '011': 168835,
#  '012': 130689,
#  '013': 83111,
#  '014': 211812,
#  '015': 373719,
#  '016': 188402,
#  '017': 379027,
#  '018': 713126,
#  '019': 476314,
#  '020': 400371,
#  '021': 1283942,
#  '022': 28215,
#  '023': 441063,
#  '024': 408771,
#  '025': 116621,
#  '026': 147883,
#  '027': 526336,
#  '028': 672977,
#  '029': 379604,
#  '030': 377547,
#  '031': 148310,
#  '032': 187843,
#  '033': 61385,
#  '034': 83919,
#  '035': 46058,
#  '036': 13759,
#  '037': 77452,
#  '038': 320300,
#  '039': 48241,
#  '040': 336449,
#  '041': 112827,
#  '042': 176789,
#  '043': 82079,
#  '044': 176589,
#  '045': 48784,
#  '046': 73776,
#  '047': 72184,
#  '048': 39786,
#  '049': 160751,
#  '050': 61355,
#  '051': 29595,
#  '052': 33424,
#  '053': 37278,
#  '054': 233934,
#  '056': 85322,
#  '057': 82488,
#  '058': 58820,
#  '059': 3525,
#  '060': 673064,
#  '061': 296589,
#  '062': 167357,
#  '063': 268711,
#  '064': 718727,
#  '065': 289828,
#  '066': 239121,
#  '067': 333407,
#  '068': 465043,
#  '069': 122486,
#  '070': 1683417,
#  '071': 395427,
#  '072': 180747,
#  '073': 247530,
#  '074': 461073,
#  '075': 198394,
#  '076': 492005,
#  '077': 601195,
#  '078': 360638,
#  '079': 256139,
#  '080': 1162373,
#  '081': 158692,
#  '082': 251979,
#  '083': 242236,
#  '084': 57555,
#  '085': 310165,
#  '086': 270100,
#  '087': 453860,
#  '088': 898011,
#  '089': 110358,
#  '100': 1502501,
#  '101': 62248,
#  '102': 12636,
#  '103': 468730,
#  '104': 1382480,
#  '105': 646012,
#  '106': 81120,
#  '107': 227049,
#  '108': 85822,
#  '109': 537311,
#  '110': 246333,
#  '111': 204715,
#  '112': 2504700,
#  '113': 1170817,
#  '114': 728928,
#  '115': 720600,
#  '116': 114978,
#  '117': 1565949,
#  '118': 72690,
#  '119': 249449,
#  '120': 330854,
#  '121': 280446,
#  '122': 151022,
#  '123': 162643,
#  '124': 154261,
#  '125': 448672,
#  '126': 86794,
#  '127': 99295,
#  '128': 225336,
#  '129': 164172,
#  '130': 388436,
#  '131': 180039,
#  '132': 229807,
#  '133': 142936,
#  '134': 187435,
#  '135': 71803,
#  '136': 236059,
#  '137': 138362,
#  '138': 139711,
#  '139': 82318,
#  '140': 444874,
#  '141': 200100,
#  '142': 564824,
#  '143': 66192,
#  '144': 304910,
#  '145': 320247,
#  '815': 143328,
#  '816': 152118,
#  '820': 128037,
#  '821': 369,
#  '822': 24524,
#  '823': 16430,
#  '824': 52930,
#  '825': 38910,
#  '826': 91238,
#  '827': 60379,
#  '828': 36958,
#  '829': 70485,
#  '830': 20661,
#  '831': 22374,
#  '832': 173456,
#  '833': 185903,
#  '834': 200744,
#  '835': 69033,
#  '836': 433929,
#  '837': 255947,
#  '838': 248514,
#  '840': 1239170,
#  '841': 594043,
#  '843': 176511,
#  '844': 186422,
#  '845': 56116,
#  '846': 287925,
#  '847': 223077,
#  '850': 1320630,
#  '851': 392144,
#  '852': 1424211,
#  '853': 1263226,
#  '855': 95187,
#  '856': 296531,
#  '857': 880383,
#  '859': 77912,
#  '860': 179367,
#  '863': 208558,
#  '864': 193625,
#  '865': 62745,
#  '870': 199596,
#  '871': 730782,
#  '873': 71938,
#  '874': 125722,
#  '875': 229936,
#  '877': 41524,
#  '878': 18552,
#  '879': 17432,
#  '880': 272577,
#  '881': 70576,
#  '882': 184020,
#  '883': 76324,
#  '884': 17370,
#  '890': 582295,
#  '891': 1418650,
#  '893': 12103,
#  '894': 290076,
#  '895': 276896,
#  '897': 66108,
#  '898': 55097,
#  '900': 2404395,
#  '902': 1240199,
#  '903': 135222,
#  '904': 92043,
#  '905': 174353,
#  '906': 726229,
#  '907': 617239,
#  '908': 471952,
#  '910': 283340,
#  '911': 166475,
#  '912': 203173,
#  '913': 1363863,
#  '914': 305280,
#  '915': 106841,
#  '916': 212915,
#  '917': 1924074,
#  '918': 83057,
#  '919': 544448,
#  '920': 1253142,
#  '921': 1294368,
#  '922': 770063,
#  '923': 1126185,
#  '924': 236660,
#  '925': 1364275,
#  '926': 1275973,
#  '927': 484908,
#  '928': 1228127,
#  '930': 687979,
#  '931': 186133,
#  '932': 778666,
#  '933': 520197,
#  '934': 491544,
#  '935': 529275,
#  '936': 586109,
#  '937': 566216,
#  '939': 385086,
#  '940': 814542,
#  '941': 805301,
#  '943': 106420,
#  '944': 131801,
#  '945': 2274102,
#  '946': 409478,
#  '947': 138207,
#  '948': 166367,
#  '949': 379560,
#  '950': 818436,
#  '951': 974040,
#  '952': 500427,
#  '953': 1023396,
#  '954': 507823,
#  '955': 166360,
#  '956': 1169245,
#  '957': 307626,
#  '958': 802578,
#  '959': 516655,
#  '960': 299938,
#  '961': 117236,
#  '967': 952871,
#  '968': 407430,
#  '970': 771280,
#  '971': 319301,
#  '972': 841711,
#  '973': 597566,
#  '974': 555743,
#  '975': 284396,
#  '976': 71254,
#  '977': 212173,
#  '978': 145632,
#  '979': 32109,
#  '980': 1348522,
#  '981': 860817,
#  '982': 877485,
#  '983': 713608,
#  '984': 400115,
#  '985': 475554,
#  '986': 573330,
#  '988': 219761,
#  '989': 284655,
#  '990': 142008,
#  '991': 115238,
#  '992': 342856,
#  '993': 348984,
#  '994': 21696,
#  '995': 320660,
#  '996': 184083,
#  '997': 134189,
#  '998': 49595,
#  '999': 21403}

# %%
assert isinstance(zip_dict, dict)
assert zip_dict['100'] == 1502501

# %% [markdown]
# ### 3f) Masking the Zip Codes
#
# In this part, you should write a for loop, updating the `df_users` dataframe.
#
# Go through each user, and update their zip code, to Safe Harbor specifications:
#
# - If the user is from a zip code for the which the "Geographic Subdivision" is less than equal to 20,000, change the zip code in df_users to '0' (as a string)
# - Otherwise, zip should be only the first 3 numbers of the full zip code
# - Do all this by directly updating the `zip` column of the `df_users` DataFrame
#
# Hints:
# 1. This will be several lines of code, looping through the DataFrame, getting each zip code, checking the geographic subdivision with the population in `zip_dict`, and setting the `zip_code` accordingly.
# 2. Be very aware of your variable types when working with zip codes here.

# %%
for ind, row in df_users.iterrows(): 
    
    if zip_dict[(str(row['zip']))[:3]] <= 20000: 
        df_users.loc[ind,'zip'] = '0' 
    else:
        df_users.loc[ind, 'zip'] = str(row['zip'])[:3]

# %%
df_users.head()
# Out:
#    age                       email first_name  gender  last_name  \
# 0   53     co'kenny7a@netscape.com    Cecilla  Female     Seeler
# 1   52       idrysdell2t@intel.com     Ingmar    Male     Maytum
# 2   52         bllewellenqr@nhs.uk     Brynne  Female    Edmunds
# 3   78             myo5x@wikia.com   Marieann     NaN     Dering
# 4   19  bcashell74@themeforest.net       Burr    Male  Bathersby
#
#         ip_address          phone  zip
# 0    187.127.90.23  (138)263-3068  010
# 1  156.241.220.163  (690)781-2853  010
# 2   60.255.124.196  (271)384-3572  010
# 3    37.118.247.19  (754)752-5841  010
# 4  201.167.247.226  (771)129-4587  013

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df_users
# Out:
#      age                                 email     first_name     gender  \
# 0     53               co'kenny7a@netscape.com        Cecilla     Female
# 1     52                 idrysdell2t@intel.com         Ingmar       Male
# 2     52                   bllewellenqr@nhs.uk         Brynne     Female
# 3     78                       myo5x@wikia.com       Marieann        NaN
# 4     19            bcashell74@themeforest.net           Burr       Male
# 5     90             rschneidarbv@geocities.jp         Rodney       Male
# 6     10                rdearmandc@comsenz.com       Robinett     Female
# 7     50                  ccaswillkg@upenn.edu           Cole       Male
# 8     84                     zrasmusej@icq.com           Zack       Male
# 9     66                  tcoulston1a@cnet.com          Tadio       Male
# 10    15             eoglethorpe29@walmart.com         Evania     Female
# 11    17             jswannh6@businesswire.com        Jacques       Male
# 12    33            sbeagrieat@list-manage.com       Simmonds       Male
# 13    57                 csewalljw@squidoo.com         Chicky       Male
# 14    51                  ndoutchey@ebay.co.uk        Nikolos       Male
# 15    72                   mmurpheyll@yale.edu           Mord       Male
# 16    50                aphillcockie@intel.com         Austin     Female
# 17    51                   cvaskin46@imgur.com          Carie     Female
# 18    22            kdraytonmi@statcounter.com        Kendell       Male
# 19    50                     ssimneliw@ucoz.ru            Say       Male
# 20    40                   ccobon2w@apache.org        Carlina     Female
# 21    31              hharteleyku@marriott.com          Honor     Female
# 22    51                    ghustler3s@loc.gov         Gasper       Male
# 23    46             aadamides51@wikimedia.org        Aurthur       Male
# 24    37   ldi pietro1f@networkadvertising.org        Lucille     Female
# 25    59              aswatheridge92@wufoo.com          Amble       Male
# 26    69                   jlemarycv@globo.com           Jock       Male
# 27    65              srenfrewr1@shinystat.com         Stacey     Female
# 28    62                   ctowardpg@slate.com           Cole       Male
# 29    43             dmatschukmd@reference.com         Dorrie     Female
# 30    29          kgallatlyde@businessweek.com         Karine     Female
# 31    34                    nsoggeepz@cnbc.com          Nicky     Female
# 32    28              hoakeshottd3@dropbox.com         Hallie     Female
# 33    73                 dhundalke@shop-pro.jp       Drusilla     Female
# 34    60              acheesemanbw@arizona.edu       Aubrette     Female
# 35     8                     dforgiehh@epa.gov           Darn       Male
# 36    21                   bmenham1y@cam.ac.uk         Bartie       Male
# 37    10            rbaleineoo@yellowpages.com            Rab       Male
# 38    69                   bebbin77@cdbaby.com          Bambi     Female
# 39    81                  sphetterq@toplist.cz          Sammy       Male
# 40    34                  alivensar@zimbio.com       Andreana     Female
# 41    15                   ckelloway1c@loc.gov         Cedric       Male
# 42    51                  mgaishson5r@digg.com        Myranda     Female
# 43    62                 pseaverspm@rediff.com      Patrizius       Male
# 44    39       nbestwerthickff@dailymail.co.uk         Nellie     Female
# 45    51                 acastles37@jalbum.net         Alanna     Female
# 46    49                  sketchell3k@cnet.com        Sansone        NaN
# 47    76              egonzalvoqu@vkontakte.ru          Emlyn       Male
# 48    47                sgrisewoodkp@ifeng.com          Shani     Female
# 49    36               pjouanetgv@marriott.com       Penelope     Female
# 50    17                 ebonelliegg@prlog.org          Elita     Female
# 51    54                     sdythamoq@ftc.gov         Sloane       Male
# 52    39                 kpasticznyki2@ovh.net         Kimble       Male
# 53    47                 lbranche4a@nsw.gov.au          Laird       Male
# 54    22                 gchaunceae@abc.net.au          Glory     Female
# 55    49                 mmcclary1x@netlog.com        Minetta     Female
# 56    77                   sliveing7c@etsy.com       Scarface       Male
# 57    20            dmorrisond6@shutterfly.com          Danya     Female
# 58    39              ssilbermann3i@meetup.com          Sioux     Female
# 59    41               ckarpeevqc@edublogs.org       Carleton       Male
# 60    47                 nwanjekqt@behance.net         Nolana     Female
# 61    25                 cwisker5j@samsung.com       Cindelyn     Female
# 62    54                  dcluley2l@apache.org           Dell       Male
# 63    54             efreearl9@dailymotion.com       Emmaline     Female
# 64    37               mpaolicchir5@utexas.edu         Mellie     Female
# 65    53                     cwickett6s@wp.com       Claudine     Female
# 66    64                 hdobrowskif3@digg.com          Herve       Male
# 67    31                    rnatte8y@sogou.com        Rebecca     Female
# 68    37                egoodsallju@disqus.com           Eric       Male
# 69    23                fbarucheu@virginia.edu          Fanny     Female
# 70    57                   bwelmanq5@google.es           Brit       Male
# 71    92               afeenyfj@shutterfly.com           Arne       Male
# 72    29                  cbrognotf@ebay.co.uk           Clim       Male
# 73    61              cmccomiskiepr@google.com          Cleon       Male
# 74    46                  bchitteygc@google.nl           Bear       Male
# 75    12                 sromushkinkh@webs.com          Shina     Female
# 76     0                  vkordtcz@nbcnews.com        Vincent       Male
# 77    10              othackwray17@tinypic.com          Orlan        NaN
# 78    34                      pboxerd7@last.fm        Padriac       Male
# 79    65                fkingshottc3@sogou.com         Farrah     Female
# 80    57                   ovan arsdale7h@g.co         Oswald       Male
# 81    25        bchalkerpx@theglobeandmail.com          Buffy     Female
# 82     9                  mavramov66@github.io          Mikel       Male
# 83    45           ahearonsh1@miitbeian.gov.cn          Adria     Female
# 84    62                lmiddiffk1@plala.or.jp         Loreen     Female
# 85     9      copdenorthql@cargocollective.com           Cara     Female
# 86    36                 dhammantcx@reddit.com          Drona     Female
# 87    33             gkenwinhq@squarespace.com         Gordan       Male
# 88    28              jstollmeier1o@meetup.com         Joshia       Male
# 89    83              bdanielovitchb@jigsy.com         Berkie       Male
# 90     7               eburgisic4@springer.com        Emanuel       Male
# 91    34         smacneilagebq@accuweather.com       Sinclair       Male
# 92    31           bpaoletti6a@miibeian.gov.cn           Borg       Male
# 93    23                    gastlethv@usgs.gov           Gael     Female
# 94    20                aansett7y@facebook.com       Allistir       Male
# 95    53                      ltwidlecm@goo.gl       Lorraine     Female
# 96    38             yduncan6c@hugedomains.com        Yalonda     Female
# 97    40               iattenbrowmr@uol.com.br            Irv       Male
# 98    70           myakobowitchl1@bluehost.com      Margarete     Female
# 99    23            hskellernkw@whitehouse.gov           Herb        NaN
# 100   50                         gojeday@51.la         Gillie     Female
# 101    5                   gmckagj8@unicef.org            Gal       Male
# 102   68           okibblewhiteem@edublogs.org       Orbadiah       Male
# 103   54                 bmabsonnc@booking.com        Bertram       Male
# 104   63                rbrushneen67@europa.eu        Rosalie     Female
# 105   30                   sturridh@jalbum.net        Sonnnie     Female
# 106   44                      lollett2h@i2i.jp         Lauren       Male
# 107   22              agrisenthwaitegz@tiny.cc           Audi     Female
# 108   37           qscogginsfb@cyberchimps.com       Quintina     Female
# 109   22                 msexty5i@newsvine.com         Magnum       Male
# 110   47                jhobgen3f@usatoday.com         Jerome       Male
# 111   54           ptessierof@businesswire.com          Prent       Male
# 112   23                arickersy8j@ebay.co.uk          Allen       Male
# 113   43                   awareg4@behance.net        Arliene     Female
# 114    3                   sdurtnell8d@gnu.org       Shepperd       Male
# 115   24                       eblazidu@w3.org          Elnar       Male
# 116   40               troncelliqb@dedecms.com        Thornie       Male
# 117   51              dtollerge@whitehouse.gov        Durward       Male
# 118   65                  ishowlpy@weather.com       Ignatius       Male
# 119   20                 bborleacer3@naver.com           Beck       Male
# 120   65                      enialsj4@cmu.edu          Emmie     Female
# 121   36                  opilpovicm9@sohu.com           Orsa     Female
# 122   40                   cterren8i@nifty.com      Christean     Female
# 123   32               rreaneyre@canalblog.com           Rory     Female
# 124   57                   ifirbankd5@about.me        Isidora     Female
# 125   50              mmcganndm@cloudflare.com        Mathias       Male
# 126   61              mdampneyow@bloglovin.com          Mandi     Female
# 127   36              sdavenhallc5@nbcnews.com       Stefanie     Female
# 128   73                 aissatton@reuters.com         Agatha     Female
# 129   25               nantonopoulospv@icio.us         Noelyn     Female
# 130   35             ckits7p@blogtalkradio.com           Clim       Male
# 131   44              mmallabon6f@hatena.ne.jp          Mordy       Male
# 132   58             nledgisterlf@freewebs.com         Nickey       Male
# 133   63                 spurple56@state.tx.us         Sheffy       Male
# 134   34             eondraseki@deviantart.com      Enriqueta     Female
# 135   11             hfranseshu@techcrunch.com      Henryetta     Female
# 136   42                    vstumpaa@ifeng.com           Vina     Female
# 354   49           cglowinski8r@vistaprint.com           Caro     Female
# 355   52               gdedenhamc9@shop-pro.jp        Glenine     Female
# 356   58                     ramsdeno1@bbb.org            Reg       Male
# 357   60            idaneleteq@accuweather.com         Ilyssa     Female
# 358    6               gharringtoni3@ameblo.jp        Gusella     Female
# 359   56                   tlookero2@ocn.ne.jp          Tamar     Female
# 360   24                 gmaasziy@marriott.com       Giustina     Female
# 361   33                nemmert8u@geocities.jp          North       Male
# 362    9                 rmccullaghg2@digg.com         Rosita     Female
# 363   47                    jsegarn@sfgate.com          Jonas       Male
# 364   54                       lordfn@noaa.gov        Leopold       Male
# 365   67      kdomleoq6@nationalgeographic.com          Kelly     Female
# 366   60              cshingfielda9@tumblr.com         Carmen     Female
# 367   78              vserginsongb@smugmug.com          Vikki     Female
# 368   32                nwillcocksio@umich.edu          Nanny     Female
# 369   43      zmossop8b@scientificamerican.com          Zolly       Male
# 370   29               ccoutthart4y@oracle.com        Colline     Female
# 371   59              hfeandercn@reference.com         Harris       Male
# 372   38   cbottomley3e@nationalgeographic.com      Catherine     Female
# 373   27                   mplimmerf5@about.me          Marla     Female
# 374   29           klowcockou@odnoklassniki.ru         Kellie     Female
# 375   67              rnairne98@altervista.org           Reba     Female
# 376   41                      whallsjt@home.pl         Waneta        NaN
# 377   42              iklaiseroy@123-reg.co.uk      Inglebert       Male
# 378   65                   sleallerl@wikia.com          Selle     Female
# 379   30                  tbeaument6g@1und1.de           Toby     Female
# 380   23                sgullandai@state.tx.us       Staffard       Male
# 381   27               akillerby2@gravatar.com           Abbe       Male
# 382   65                   dmagnar42@bbc.co.uk          Denny       Male
# 383   63                   kdrayle@weather.com        Kennett       Male
# 384   42                   jdodimead78@npr.org             Jo        NaN
# 385    7                       vsagg9t@cnn.com        Vasilis       Male
# 386   35               hcapellepu@illinois.edu          Hiram       Male
# 387   35            kmcallester71@bluehost.com         Kristy     Female
# 388   85                       sharmsm8@si.edu          Stevy       Male
# 389   44                       mgrigor2z@is.gd        Margret     Female
# 390   76            ftsarovic39@soundcloud.com      Friedrick       Male
# 391   22                  apacitti83@google.ca             Ab       Male
# 392   19                 bguidoneel@apache.org        Brendis       Male
# 393   75                     nblemenpe@last.fm         Nilson       Male
# 394   46          rbaughn1n@chicagotribune.com         Rozele     Female
# 395   33                   dhrinishin7f@ed.gov            Der       Male
# 396   36            dst louisdw@feedburner.com        Damiano        NaN
# 397   64               dtraceygy@webeden.co.uk           Dell     Female
# 398   63               gbattistaad@comcast.net         Georas       Male
# 399   13           disham99@simplemachines.org         Donnie       Male
# 400   42    cweddeburn - scrimgeoura2@java.com       Charline     Female
# 401   30                     pspinas87@nps.gov       Penelope     Female
# 402   64                      imaudlin13@de.vu           Issi     Female
# 403   27            cfeechumj3@bizjournals.com        Claudie     Female
# 404   65                    afawlkesqs@nps.gov      Aprilette     Female
# 405   38            ppancastom@arstechnica.com        Padraig       Male
# 406   29                mpriestland7@opera.com        Manfred       Male
# 407   49                   mvinaukj@drupal.org       Madelena     Female
# 408   45                  mbiever6u@uol.com.br         Marena     Female
# 409   37            sjobling9n@dailymotion.com          Simon       Male
# 410   23               hcrocettone@smugmug.com           Hope     Female
# 411   47                    eweaben1@salon.com        Elenore     Female
# 412   48                   bblague3b@zdnet.com          Biron       Male
# 413   61                bhansekt@shinystat.com        Brandtr       Male
# 414   45               cniced4@miibeian.gov.cn          Carly       Male
# 415   59             kmcglashan3d@redcross.org          Kaine       Male
# 416   21                  pcousenf1@rediff.com         Phelia     Female
# 417   32         vo'heneghanqw@dailymail.co.uk          Vance       Male
# 418   37               hwooldridge1i@globo.com          Hersh       Male
# 419   28                   zgilbey75@webmd.com       Zaccaria  Nonbinary
# 420   55           cboothroydrj@yellowbook.com       Charlena        NaN
# 421   33           rbrandindl@domainmarket.com         Rickie       Male
# 422   64              kpatifield1b@jiathis.com        Kennith       Male
# 423   48                     smcfatercs@wp.com         Shalom       Male
# 424   61             vverillo50@techcrunch.com        Vincent       Male
# 425   33              sfitteroi@infoseek.co.jp        Sabrina     Female
# 426   41              wschulelx@wikispaces.com         Wendel       Male
# 427   38               crevening2b@alibaba.com         Celina     Female
# 428   20                nalvarez58@twitter.com            Nat     Female
# 429   35            mseckingtono4@geocities.jp        Malcolm       Male
# 430   39           clissandrin5@wikispaces.com           Conn       Male
# 431   24                 cbracknellg7@blog.com        Charity     Female
# 432   28                  civoryjh@histats.com            Cyb     Female
# 433   45                   joakman2g@jimdo.com       Jefferey       Male
# 434   21              kjoseburyit@geocities.jp        Karlene     Female
# 435   86                 fstovejr@bandcamp.com        Flossie     Female
# 436   34               glosselyong8n@naver.com       Germayne       Male
# 437   47            dmaguire84@livejournal.com       Demetria     Female
# 438   42               emunnisf2@canalblog.com         Edmund       Male
# 439   28                tashburnees@rambler.ru         Tobiah        NaN
# 440   60               ldankersley7j@mysql.com         Lauree     Female
# 441   30                    sincogna6o@psu.edu            Sky       Male
# 442   22                    cpardeybm@digg.com     Clementius       Male
# 443   21               ro'hartnettb7@google.es       Reinwald       Male
# 444   63              nmccamishmz@slashdot.org         Noreen     Female
# 445   45                   azealykz@eepurl.com        Agnesse     Female
# 446   51                mbirchhg@bigcartel.com          Morey       Male
# 447   45                celsie9j@delicious.com        Callean       Male
# 448   75           pmortlockrp@liveinternet.ru           Paco       Male
# 449   66                amograe0@google.com.au        Amandie     Female
# 450   36                rcerro72@pinterest.com        Richart       Male
# 451   70                       sscrase73@51.la        Stanton       Male
# 452   48                     szelnerpa@tiny.cc         Sheela     Female
# 453   34                  mfindenp7@hao123.com         Martie     Female
# 454   84           vvalens-smithqk@behance.net       Valentia     Female
# 455   50                  sdunkerley8k@cdc.gov         Sharyl     Female
# 456   43                    nholston5e@unc.edu      Nikoletta     Female
# 457   43                    tbelisoni4@fda.gov       Terri-jo        NaN
# 458   86                     lcainsln@dell.com           Luce       Male
# 459   59                   bwillmettl2@gnu.org           Bart       Male
# 460   14                   rflawithks@fema.gov        Rhianna     Female
# 461    5                      bkynson44@ft.com        Barnett       Male
# 462   31                    nhugliin@mysql.com          Noemi     Female
# 463   38            hwateridge16@instagram.com          Hewie       Male
# 909         Peachman     150.180.4.33  (684)372-0353  956
# 910          Jiggins    159.44.36.112  (341)545-2585  958
# 911        Malkinson   132.228.150.37  (718)984-0979  959
# 912          Hanhard   202.44.128.125  (401)970-2673  961
# 913            Cruft    108.120.73.71  (262)879-6602  961
# 914           Tetley     82.233.62.39  (666)800-4626  961
# 915         Scourgie    65.157.241.37  (187)118-5443  967
# 916          Denison     28.243.72.29  (920)742-0040  970
# 917        Hanington    29.61.213.192  (919)367-4155  970
# 918            Crook    191.60.161.59  (290)879-3393  971
# 919          Gatrill  201.184.255.223  (913)914-2917  971
# 920          Readman    200.185.91.12  (706)222-8876  971
# 921           Wallas   209.191.63.172  (621)531-4875  973
# 922            Reyes    63.80.125.147  (754)748-2047  974
# 923           Bugden    46.75.137.149  (661)868-5599  974
# 924            Fenna    139.252.66.54  (871)952-6568  974
# 925         Florence     103.22.16.47  (224)799-2466  975
# 926           Sisson    16.251.91.255  (645)178-3982  977
# 927          Cattlow   183.130.185.65  (894)186-1514  978
# 928            Barde    86.81.145.219  (678)997-5536  978
# 929           Ringer      67.82.223.3  (642)763-5879  979
# 930          Bendley    39.47.253.182  (185)375-0188  980
# 931          Charlot   157.65.138.110  (177)383-8180  981
# 932          Kiledal    69.234.140.25  (944)549-8444  982
# 933          McCahey    236.12.33.177  (839)273-8544  982
# 934           Worner     58.73.212.78  (553)296-0134  983
# 935          Couvert  245.192.127.200  (974)660-0452  985
# 936            Marsy    164.13.253.57  (746)900-3948  985
# 937         Piscotti   27.223.183.246  (959)754-5291  985
# 938          Mallaby   167.49.173.177  (310)335-1341  988
# 939       Hanselmann   108.80.132.168  (670)954-3502  989
# 940         Sauniere   153.139.187.25  (668)791-6367  992
# 941         Oliveras   50.123.231.233  (770)433-7193  993
# 942           Ducroe  190.204.190.126  (865)302-7167  993
# 943           Cubbin  237.234.183.188  (864)791-6285  995
# 944         Ettritch     40.2.146.154  (154)177-5531  996
# 945            Jorio      113.57.4.98  (137)550-2985  996
# 946          Baldwin    231.3.134.240  (223)291-5317  996
# 947        Mulderrig    47.194.212.99  (263)262-6051  997
# 948        Kingswell     51.17.58.226  (241)212-9527  997
# 949       Meiklejohn    84.39.195.178  (123)517-5409  997

# %%
assert len(df_users) == 943
assert df_users.loc[671, 'zip'] == '687'
assert sum(df_users.zip == '0') > 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-55-96c47da1e74f> in <module>
# ----> 1 assert len(df_users) == 943
#       2 assert df_users.loc[671, 'zip'] == '687'
#       3 assert sum(df_users.zip == '0') > 0
#
# AssertionError:

# %% [markdown]
# ### 3g) Save out the properly anonymized data to json file
#
# Save out `df_users` as a json file, called `real_anon_user_dat.json`

# %%
df_users.to_json('real_anon_user_dat.json')

# %%
assert isinstance(pd.read_json('real_anon_user_dat.json'), pd.DataFrame)

# %% [markdown]
# ## Complete!
#
# Congrats, you're done! The users' identities are much more protected now.
#
# Have a look back over your answers, and also make sure to `Restart & Run All` from the kernel menu to double check that everything is working properly. You can also use the 'Validate' button above, which runs your notebook from top to bottom and checks to ensure all `assert` statements pass silently. When you are ready, submit on datahub!
